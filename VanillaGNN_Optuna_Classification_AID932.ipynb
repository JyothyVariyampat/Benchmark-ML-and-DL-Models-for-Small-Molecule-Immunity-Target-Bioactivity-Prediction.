# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn.functional as F
from torch_geometric.loader import DataLoader
from torch_geometric.utils import from_smiles
from torch.nn import Linear, BatchNorm1d, Dropout
from torch_geometric.nn import global_mean_pool
from sklearn.metrics import roc_auc_score, f1_score, cohen_kappa_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
import optuna
import os
import random

# Set random seed for reproducibility
def seed_set(seed=50):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)

seed_set()

# Define device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load your dataset
df_final = pd.read_csv('AID932_data_for_classification_08Nov2024.csv')

# Preprocess data and create graph list
graph_list = []
for i, smile in enumerate(df_final['SMILES']):
    try:
        g = from_smiles(smile)
        g.x = g.x.float()
        y_value = 1.0 if df_final['PUBCHEM_ACTIVITY_OUTCOME'][i] == 'Active' else 0.0
        y = torch.tensor(y_value, dtype=torch.float).view(1, -1)
        g.y = y
        graph_list.append(g)
    except Exception as e:
        print(f"Error processing SMILES {smile}: {e}")
        continue

# Stratified split of dataset into train and test sets
labels = [g.y.item() for g in graph_list]
train_dataset, test_dataset = train_test_split(graph_list, test_size=0.2, stratify=labels, random_state=50)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Define Vanilla GNN Model
class VanillaGNN(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout_rate=0.3):
        super(VanillaGNN, self).__init__()
        self.fc1 = Linear(input_dim, hidden_dim)
        self.bn1 = BatchNorm1d(hidden_dim)
        self.fc2 = Linear(hidden_dim, hidden_dim)
        self.bn2 = BatchNorm1d(hidden_dim)
        self.fc3 = Linear(hidden_dim, hidden_dim)
        self.bn3 = BatchNorm1d(hidden_dim)
        self.fc_out = Linear(hidden_dim, output_dim)
        self.dropout = Dropout(p=dropout_rate)

    def forward(self, data):
        x, batch = data.x, data.batch
        x = F.relu(self.bn1(self.fc1(x)))
        x = self.dropout(x)
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.dropout(x)
        x = F.relu(self.bn3(self.fc3(x)))
        x = self.dropout(x)
        x = global_mean_pool(x, batch)
        return torch.sigmoid(self.fc_out(x))

# Training function
def train(model, loader, optimizer):
    model.train()
    total_loss, correct = 0, 0
    all_preds, all_labels = [], []
    for data in loader:
        data = data.to(device)
        optimizer.zero_grad()
        out = model(data)
        loss = F.binary_cross_entropy(out, data.y.view(-1, 1))
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
        preds = (out > 0.5).float()
        correct += (preds == data.y.view(-1, 1)).sum().item()
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(data.y.cpu().numpy())
    accuracy = correct / len(loader.dataset)
    roc_auc = roc_auc_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds)
    kappa = cohen_kappa_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds)
    recall = recall_score(all_labels, all_preds)
    return total_loss / len(loader.dataset), accuracy, roc_auc, f1, kappa, precision, recall

# Testing function
@torch.no_grad()
def test(model, loader):
    model.eval()
    total_loss, correct = 0, 0
    all_preds, all_labels = [], []
    for data in loader:
        data = data.to(device)
        out = model(data)
        loss = F.binary_cross_entropy(out, data.y.view(-1, 1))
        total_loss += loss.item() * data.num_graphs
        preds = (out > 0.5).float()
        correct += (preds == data.y.view(-1, 1)).sum().item()
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(data.y.cpu().numpy())
    accuracy = correct / len(loader.dataset)
    roc_auc = roc_auc_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds)
    kappa = cohen_kappa_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds)
    recall = recall_score(all_labels, all_preds)
    return total_loss / len(loader.dataset), accuracy, roc_auc, f1, kappa, precision, recall

# Optuna objective function for hyperparameter optimization
def objective(trial):
    hidden_dim = trial.suggest_int("hidden_dim", 32, 128)
    dropout_rate = trial.suggest_float("dropout_rate", 0.1, 0.5)
    learning_rate = trial.suggest_float("learning_rate", 1e-4, 1e-2, log=True)
    weight_decay = trial.suggest_float("weight_decay", 1e-6, 1e-4, log=True)

    model = VanillaGNN(input_dim=9, hidden_dim=hidden_dim, output_dim=1, dropout_rate=dropout_rate).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

    for epoch in range(20):
        train_loss, train_acc, _, _, _, _, _ = train(model, train_loader, optimizer)

    test_loss, test_acc, _, _, _, _, _ = test(model, test_loader)
    return test_acc

# Run Optuna for hyperparameter optimization
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=20)

# Best hyperparameters from Optuna
best_params = study.best_params
print("Best hyperparameters:", best_params)

# Initialize model with best hyperparameters
model = VanillaGNN(input_dim=9, hidden_dim=best_params["hidden_dim"], output_dim=1, dropout_rate=best_params["dropout_rate"]).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=best_params["learning_rate"], weight_decay=best_params["weight_decay"])

# Training loop with all metrics tracking
epochs = 75
score_train_loss, score_train_acc = [], []
score_test_loss, score_test_acc = [], []
score_roc_auc, score_f1, score_kappa = [], [], []
score_precision, score_recall = [], []

for epoch in range(epochs):
    train_loss, train_acc, train_roc_auc, train_f1, train_kappa, train_precision, train_recall = train(model, train_loader, optimizer)
    test_loss, test_acc, test_roc_auc, test_f1, test_kappa, test_precision, test_recall = test(model, test_loader)

    score_train_loss.append(train_loss)
    score_train_acc.append(train_acc)
    score_test_loss.append(test_loss)
    score_test_acc.append(test_acc)
    score_roc_auc.append(test_roc_auc)
    score_f1.append(test_f1)
    score_kappa.append(test_kappa)
    score_precision.append(test_precision)
    score_recall.append(test_recall)

    print(f'Epoch {epoch:03d}: Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}, '
          f'ROC AUC: {test_roc_auc:.4f}, F1: {test_f1:.4f}, Kappa: {test_kappa:.4f}, '
          f'Precision: {test_precision:.4f}, Recall: {test_recall:.4f}')

# Plotting results
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(range(epochs), score_train_loss, label='Train Loss')
plt.plot(range(epochs), score_test_loss, label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(epochs), score_train_acc, label='Train Accuracy')
plt.plot(range(epochs), score_test_acc, label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
# Out:
# [I 2024-11-18 17:54:28,075] A new study created in memory with name: no-name-e4d62ca7-ee69-4c5d-9a05-d81755310063
# [I 2024-11-18 17:54:39,690] Trial 0 finished with value: 0.695 and parameters: {'hidden_dim': 116, 'dropout_rate': 0.11536265302316534, 'learning_rate': 0.0031414148041783102, 'weight_decay': 1.1926006092603131e-05}. Best is trial 0 with value: 0.695.
# [I 2024-11-18 17:54:52,537] Trial 1 finished with value: 0.675 and parameters: {'hidden_dim': 63, 'dropout_rate': 0.46886471513862693, 'learning_rate': 0.0004920110700884101, 'weight_decay': 6.60621659451584e-05}. Best is trial 0 with value: 0.695.
# [I 2024-11-18 17:55:04,768] Trial 2 finished with value: 0.72 and parameters: {'hidden_dim': 79, 'dropout_rate': 0.12260654942344439, 'learning_rate': 0.0004803912954857389, 'weight_decay': 4.4819542667732356e-06}. Best is trial 2 with value: 0.72.
# [I 2024-11-18 17:55:16,382] Trial 3 finished with value: 0.6925 and parameters: {'hidden_dim': 43, 'dropout_rate': 0.4615223713558968, 'learning_rate': 0.0002247942890579855, 'weight_decay': 5.314714078218986e-05}. Best is trial 2 with value: 0.72.
# [I 2024-11-18 17:55:28,586] Trial 4 finished with value: 0.715 and parameters: {'hidden_dim': 122, 'dropout_rate': 0.46209428923200335, 'learning_rate': 0.0016853428941486686, 'weight_decay': 6.868785994593936e-05}. Best is trial 2 with value: 0.72.
# [I 2024-11-18 17:55:41,218] Trial 5 finished with value: 0.72625 and parameters: {'hidden_dim': 67, 'dropout_rate': 0.14972762877671905, 'learning_rate': 0.0031497526101988715, 'weight_decay': 1.4118039106968508e-06}. Best is trial 5 with value: 0.72625.
# [I 2024-11-18 17:55:53,435] Trial 6 finished with value: 0.7175 and parameters: {'hidden_dim': 86, 'dropout_rate': 0.1939320443980006, 'learning_rate': 0.005976200812623544, 'weight_decay': 1.2729080026159562e-06}. Best is trial 5 with value: 0.72625.
# [I 2024-11-18 17:56:06,234] Trial 7 finished with value: 0.71625 and parameters: {'hidden_dim': 122, 'dropout_rate': 0.4510207311279578, 'learning_rate': 0.0005953822627784904, 'weight_decay': 3.168437365307068e-05}. Best is trial 5 with value: 0.72625.
# [I 2024-11-18 17:56:18,278] Trial 8 finished with value: 0.715 and parameters: {'hidden_dim': 61, 'dropout_rate': 0.2640084748663887, 'learning_rate': 0.0005152241989176188, 'weight_decay': 8.143173432564333e-05}. Best is trial 5 with value: 0.72625.
# [I 2024-11-18 17:56:29,949] Trial 9 finished with value: 0.695 and parameters: {'hidden_dim': 40, 'dropout_rate': 0.48022542683530356, 'learning_rate': 0.0002941853678047615, 'weight_decay': 2.2922357904222398e-05}. Best is trial 5 with value: 0.72625.
# [I 2024-11-18 17:56:41,569] Trial 10 finished with value: 0.7325 and parameters: {'hidden_dim': 96, 'dropout_rate': 0.344766469993015, 'learning_rate': 0.008985090994756143, 'weight_decay': 1.023134232745973e-06}. Best is trial 10 with value: 0.7325.
# [I 2024-11-18 17:56:53,576] Trial 11 finished with value: 0.72125 and parameters: {'hidden_dim': 97, 'dropout_rate': 0.3610292973727406, 'learning_rate': 0.009980084075778148, 'weight_decay': 1.057720426030479e-06}. Best is trial 10 with value: 0.7325.
# [I 2024-11-18 17:57:05,391] Trial 12 finished with value: 0.7275 and parameters: {'hidden_dim': 103, 'dropout_rate': 0.3290092433270436, 'learning_rate': 0.0032387799504830575, 'weight_decay': 2.5188574943179435e-06}. Best is trial 10 with value: 0.7325.
# [I 2024-11-18 17:57:17,450] Trial 13 finished with value: 0.69875 and parameters: {'hidden_dim': 103, 'dropout_rate': 0.34652559367494956, 'learning_rate': 0.004840891536044574, 'weight_decay': 3.2024257061465773e-06}. Best is trial 10 with value: 0.7325.
# [I 2024-11-18 17:57:30,152] Trial 14 finished with value: 0.72375 and parameters: {'hidden_dim': 105, 'dropout_rate': 0.28932720806343926, 'learning_rate': 0.0014814242685886787, 'weight_decay': 2.866756140763918e-06}. Best is trial 10 with value: 0.7325.
# [I 2024-11-18 17:57:42,433] Trial 15 finished with value: 0.69625 and parameters: {'hidden_dim': 89, 'dropout_rate': 0.38288519320099146, 'learning_rate': 0.009871607734854225, 'weight_decay': 5.87450397220036e-06}. Best is trial 10 with value: 0.7325.
# [I 2024-11-18 17:57:55,427] Trial 16 finished with value: 0.71 and parameters: {'hidden_dim': 109, 'dropout_rate': 0.22494549886203447, 'learning_rate': 0.002464214234885632, 'weight_decay': 2.1335308492711416e-06}. Best is trial 10 with value: 0.7325.
# [I 2024-11-18 17:58:08,229] Trial 17 finished with value: 0.67875 and parameters: {'hidden_dim': 75, 'dropout_rate': 0.4062851136453294, 'learning_rate': 0.005890262131842986, 'weight_decay': 8.336236091626642e-06}. Best is trial 10 with value: 0.7325.
# [I 2024-11-18 17:58:20,645] Trial 18 finished with value: 0.7075 and parameters: {'hidden_dim': 94, 'dropout_rate': 0.32206228669826076, 'learning_rate': 0.0001076486314828079, 'weight_decay': 1.867041356129485e-06}. Best is trial 10 with value: 0.7325.
# [I 2024-11-18 17:58:33,034] Trial 19 finished with value: 0.7225 and parameters: {'hidden_dim': 114, 'dropout_rate': 0.41160648050641524, 'learning_rate': 0.0010437491713544173, 'weight_decay': 3.5950959408579836e-06}. Best is trial 10 with value: 0.7325.
# Best hyperparameters: {'hidden_dim': 96, 'dropout_rate': 0.344766469993015, 'learning_rate': 0.008985090994756143, 'weight_decay': 1.023134232745973e-06}
# Epoch 000: Train Acc: 0.6637, Test Acc: 0.5900, ROC AUC: 0.5900, F1: 0.7018, Kappa: 0.1800, Precision: 0.5514, Recall: 0.9650
# Epoch 001: Train Acc: 0.7019, Test Acc: 0.6088, ROC AUC: 0.6087, F1: 0.7094, Kappa: 0.2175, Precision: 0.5643, Recall: 0.9550
# Epoch 002: Train Acc: 0.7050, Test Acc: 0.6325, ROC AUC: 0.6325, F1: 0.7200, Kappa: 0.2650, Precision: 0.5815, Recall: 0.9450
# Epoch 003: Train Acc: 0.7091, Test Acc: 0.7037, ROC AUC: 0.7037, F1: 0.7393, Kappa: 0.4075, Precision: 0.6601, Recall: 0.8400
# Epoch 004: Train Acc: 0.7094, Test Acc: 0.6987, ROC AUC: 0.6987, F1: 0.7533, Kappa: 0.3975, Precision: 0.6378, Recall: 0.9200
# Epoch 005: Train Acc: 0.7084, Test Acc: 0.6887, ROC AUC: 0.6887, F1: 0.7457, Kappa: 0.3775, Precision: 0.6304, Recall: 0.9125
# Epoch 006: Train Acc: 0.7188, Test Acc: 0.7200, ROC AUC: 0.7200, F1: 0.7477, Kappa: 0.4400, Precision: 0.6803, Recall: 0.8300
# Epoch 007: Train Acc: 0.7128, Test Acc: 0.7212, ROC AUC: 0.7212, F1: 0.6999, Kappa: 0.4425, Precision: 0.7580, Recall: 0.6500
# Epoch 008: Train Acc: 0.7209, Test Acc: 0.7225, ROC AUC: 0.7225, F1: 0.7533, Kappa: 0.4450, Precision: 0.6780, Recall: 0.8475
# Epoch 009: Train Acc: 0.7238, Test Acc: 0.6900, ROC AUC: 0.6900, F1: 0.7475, Kappa: 0.3800, Precision: 0.6306, Recall: 0.9175
# Epoch 010: Train Acc: 0.7178, Test Acc: 0.7188, ROC AUC: 0.7188, F1: 0.7411, Kappa: 0.4375, Precision: 0.6866, Recall: 0.8050
# Epoch 011: Train Acc: 0.7291, Test Acc: 0.7188, ROC AUC: 0.7187, F1: 0.6922, Kappa: 0.4375, Precision: 0.7644, Recall: 0.6325
# Epoch 012: Train Acc: 0.7300, Test Acc: 0.7113, ROC AUC: 0.7112, F1: 0.7072, Kappa: 0.4225, Precision: 0.7172, Recall: 0.6975
# Epoch 013: Train Acc: 0.7216, Test Acc: 0.7075, ROC AUC: 0.7075, F1: 0.7537, Kappa: 0.4150, Precision: 0.6509, Recall: 0.8950
# Epoch 014: Train Acc: 0.7156, Test Acc: 0.6438, ROC AUC: 0.6438, F1: 0.7283, Kappa: 0.2875, Precision: 0.5886, Recall: 0.9550
# Epoch 015: Train Acc: 0.7203, Test Acc: 0.7262, ROC AUC: 0.7263, F1: 0.7468, Kappa: 0.4525, Precision: 0.6946, Recall: 0.8075
# Epoch 016: Train Acc: 0.7225, Test Acc: 0.7225, ROC AUC: 0.7225, F1: 0.7204, Kappa: 0.4450, Precision: 0.7259, Recall: 0.7150
# Epoch 017: Train Acc: 0.7231, Test Acc: 0.7225, ROC AUC: 0.7225, F1: 0.7539, Kappa: 0.4450, Precision: 0.6773, Recall: 0.8500
# Epoch 018: Train Acc: 0.7212, Test Acc: 0.7262, ROC AUC: 0.7262, F1: 0.7339, Kappa: 0.4525, Precision: 0.7139, Recall: 0.7550
# Epoch 019: Train Acc: 0.7209, Test Acc: 0.7175, ROC AUC: 0.7175, F1: 0.7372, Kappa: 0.4350, Precision: 0.6891, Recall: 0.7925
# Epoch 020: Train Acc: 0.7312, Test Acc: 0.7250, ROC AUC: 0.7250, F1: 0.7243, Kappa: 0.4500, Precision: 0.7261, Recall: 0.7225
# Epoch 021: Train Acc: 0.7272, Test Acc: 0.7300, ROC AUC: 0.7300, F1: 0.7143, Kappa: 0.4600, Precision: 0.7584, Recall: 0.6750
# Epoch 022: Train Acc: 0.7222, Test Acc: 0.7212, ROC AUC: 0.7213, F1: 0.7480, Kappa: 0.4425, Precision: 0.6825, Recall: 0.8275
# Epoch 023: Train Acc: 0.7212, Test Acc: 0.7225, ROC AUC: 0.7225, F1: 0.6856, Kappa: 0.4450, Precision: 0.7908, Recall: 0.6050
# Epoch 024: Train Acc: 0.7203, Test Acc: 0.7262, ROC AUC: 0.7263, F1: 0.7468, Kappa: 0.4525, Precision: 0.6946, Recall: 0.8075
# Epoch 025: Train Acc: 0.7400, Test Acc: 0.7075, ROC AUC: 0.7075, F1: 0.7285, Kappa: 0.4150, Precision: 0.6797, Recall: 0.7850
# Epoch 026: Train Acc: 0.7284, Test Acc: 0.7188, ROC AUC: 0.7188, F1: 0.7525, Kappa: 0.4375, Precision: 0.6719, Recall: 0.8550
# Epoch 027: Train Acc: 0.7272, Test Acc: 0.7137, ROC AUC: 0.7137, F1: 0.7211, Kappa: 0.4275, Precision: 0.7031, Recall: 0.7400
# Epoch 028: Train Acc: 0.7175, Test Acc: 0.7200, ROC AUC: 0.7200, F1: 0.7321, Kappa: 0.4400, Precision: 0.7018, Recall: 0.7650
# Epoch 029: Train Acc: 0.7275, Test Acc: 0.7137, ROC AUC: 0.7137, F1: 0.7053, Kappa: 0.4275, Precision: 0.7268, Recall: 0.6850
# Epoch 030: Train Acc: 0.7262, Test Acc: 0.7113, ROC AUC: 0.7112, F1: 0.7453, Kappa: 0.4225, Precision: 0.6667, Recall: 0.8450
# Epoch 031: Train Acc: 0.7244, Test Acc: 0.7150, ROC AUC: 0.7150, F1: 0.7077, Kappa: 0.4300, Precision: 0.7263, Recall: 0.6900
# Epoch 032: Train Acc: 0.7241, Test Acc: 0.7212, ROC AUC: 0.7213, F1: 0.7100, Kappa: 0.4425, Precision: 0.7398, Recall: 0.6825
# Epoch 033: Train Acc: 0.7266, Test Acc: 0.6975, ROC AUC: 0.6975, F1: 0.7546, Kappa: 0.3950, Precision: 0.6348, Recall: 0.9300
# Epoch 034: Train Acc: 0.7319, Test Acc: 0.7087, ROC AUC: 0.7087, F1: 0.6686, Kappa: 0.4175, Precision: 0.7756, Recall: 0.5875
# Epoch 035: Train Acc: 0.7212, Test Acc: 0.7087, ROC AUC: 0.7088, F1: 0.7508, Kappa: 0.4175, Precision: 0.6561, Recall: 0.8775
# Epoch 036: Train Acc: 0.7241, Test Acc: 0.7113, ROC AUC: 0.7112, F1: 0.7459, Kappa: 0.4225, Precision: 0.6660, Recall: 0.8475
# Epoch 037: Train Acc: 0.7241, Test Acc: 0.7137, ROC AUC: 0.7137, F1: 0.7190, Kappa: 0.4275, Precision: 0.7060, Recall: 0.7325
# Epoch 038: Train Acc: 0.7256, Test Acc: 0.7275, ROC AUC: 0.7275, F1: 0.7386, Kappa: 0.4550, Precision: 0.7097, Recall: 0.7700
# Epoch 039: Train Acc: 0.7297, Test Acc: 0.7225, ROC AUC: 0.7225, F1: 0.7472, Kappa: 0.4450, Precision: 0.6862, Recall: 0.8200
# Epoch 040: Train Acc: 0.7250, Test Acc: 0.7175, ROC AUC: 0.7175, F1: 0.7154, Kappa: 0.4350, Precision: 0.7208, Recall: 0.7100
# Epoch 041: Train Acc: 0.7256, Test Acc: 0.7188, ROC AUC: 0.7188, F1: 0.7198, Kappa: 0.4375, Precision: 0.7171, Recall: 0.7225
# Epoch 042: Train Acc: 0.7331, Test Acc: 0.7150, ROC AUC: 0.7150, F1: 0.7305, Kappa: 0.4300, Precision: 0.6928, Recall: 0.7725
# Epoch 043: Train Acc: 0.7278, Test Acc: 0.7200, ROC AUC: 0.7200, F1: 0.7214, Kappa: 0.4400, Precision: 0.7178, Recall: 0.7250
# Epoch 044: Train Acc: 0.7331, Test Acc: 0.7137, ROC AUC: 0.7137, F1: 0.6967, Kappa: 0.4275, Precision: 0.7408, Recall: 0.6575
# Epoch 045: Train Acc: 0.7228, Test Acc: 0.7063, ROC AUC: 0.7062, F1: 0.7560, Kappa: 0.4125, Precision: 0.6465, Recall: 0.9100
# Epoch 046: Train Acc: 0.7262, Test Acc: 0.7150, ROC AUC: 0.7150, F1: 0.7213, Kappa: 0.4300, Precision: 0.7057, Recall: 0.7375
# Epoch 047: Train Acc: 0.7231, Test Acc: 0.7225, ROC AUC: 0.7225, F1: 0.7299, Kappa: 0.4450, Precision: 0.7109, Recall: 0.7500
# Epoch 048: Train Acc: 0.7250, Test Acc: 0.7163, ROC AUC: 0.7163, F1: 0.6945, Kappa: 0.4325, Precision: 0.7522, Recall: 0.6450
# Epoch 049: Train Acc: 0.7328, Test Acc: 0.7175, ROC AUC: 0.7175, F1: 0.7438, Kappa: 0.4350, Precision: 0.6805, Recall: 0.8200
# Epoch 050: Train Acc: 0.7303, Test Acc: 0.7175, ROC AUC: 0.7175, F1: 0.7420, Kappa: 0.4350, Precision: 0.6828, Recall: 0.8125
# Epoch 051: Train Acc: 0.7197, Test Acc: 0.7163, ROC AUC: 0.7162, F1: 0.7255, Kappa: 0.4325, Precision: 0.7026, Recall: 0.7500
# Epoch 052: Train Acc: 0.7212, Test Acc: 0.7163, ROC AUC: 0.7163, F1: 0.7294, Kappa: 0.4325, Precision: 0.6970, Recall: 0.7650
# Epoch 053: Train Acc: 0.7309, Test Acc: 0.7087, ROC AUC: 0.7087, F1: 0.7476, Kappa: 0.4175, Precision: 0.6597, Recall: 0.8625
# Epoch 054: Train Acc: 0.7275, Test Acc: 0.7175, ROC AUC: 0.7175, F1: 0.7271, Kappa: 0.4350, Precision: 0.7033, Recall: 0.7525
# Epoch 055: Train Acc: 0.7256, Test Acc: 0.7200, ROC AUC: 0.7200, F1: 0.7327, Kappa: 0.4400, Precision: 0.7009, Recall: 0.7675
# Epoch 056: Train Acc: 0.7269, Test Acc: 0.7188, ROC AUC: 0.7188, F1: 0.7417, Kappa: 0.4375, Precision: 0.6858, Recall: 0.8075
# Epoch 057: Train Acc: 0.7325, Test Acc: 0.7150, ROC AUC: 0.7150, F1: 0.7379, Kappa: 0.4300, Precision: 0.6830, Recall: 0.8025
# Epoch 058: Train Acc: 0.7291, Test Acc: 0.7100, ROC AUC: 0.7100, F1: 0.6931, Kappa: 0.4200, Precision: 0.7360, Recall: 0.6550
# Epoch 059: Train Acc: 0.7288, Test Acc: 0.7288, ROC AUC: 0.7288, F1: 0.7370, Kappa: 0.4575, Precision: 0.7153, Recall: 0.7600
# Epoch 060: Train Acc: 0.7234, Test Acc: 0.7113, ROC AUC: 0.7113, F1: 0.7519, Kappa: 0.4225, Precision: 0.6591, Recall: 0.8750
# Epoch 061: Train Acc: 0.7309, Test Acc: 0.7163, ROC AUC: 0.7162, F1: 0.7572, Kappa: 0.4325, Precision: 0.6617, Recall: 0.8850
# Epoch 062: Train Acc: 0.7203, Test Acc: 0.7300, ROC AUC: 0.7300, F1: 0.7410, Kappa: 0.4600, Precision: 0.7120, Recall: 0.7725
# Epoch 063: Train Acc: 0.7312, Test Acc: 0.7175, ROC AUC: 0.7175, F1: 0.7251, Kappa: 0.4350, Precision: 0.7062, Recall: 0.7450
# Epoch 064: Train Acc: 0.7284, Test Acc: 0.7175, ROC AUC: 0.7175, F1: 0.7080, Kappa: 0.4350, Precision: 0.7326, Recall: 0.6850
# Epoch 065: Train Acc: 0.7338, Test Acc: 0.7188, ROC AUC: 0.7188, F1: 0.7312, Kappa: 0.4375, Precision: 0.7002, Recall: 0.7650
# Epoch 066: Train Acc: 0.7303, Test Acc: 0.7212, ROC AUC: 0.7213, F1: 0.7264, Kappa: 0.4425, Precision: 0.7133, Recall: 0.7400
# Epoch 067: Train Acc: 0.7175, Test Acc: 0.7200, ROC AUC: 0.7200, F1: 0.7477, Kappa: 0.4400, Precision: 0.6803, Recall: 0.8300
# Epoch 068: Train Acc: 0.7241, Test Acc: 0.7150, ROC AUC: 0.7150, F1: 0.7500, Kappa: 0.4300, Precision: 0.6680, Recall: 0.8550
# Epoch 069: Train Acc: 0.7238, Test Acc: 0.7175, ROC AUC: 0.7175, F1: 0.7103, Kappa: 0.4350, Precision: 0.7289, Recall: 0.6925
# Epoch 070: Train Acc: 0.7241, Test Acc: 0.7150, ROC AUC: 0.7150, F1: 0.7500, Kappa: 0.4300, Precision: 0.6680, Recall: 0.8550
# Epoch 071: Train Acc: 0.7275, Test Acc: 0.7100, ROC AUC: 0.7100, F1: 0.7393, Kappa: 0.4200, Precision: 0.6714, Recall: 0.8225
# Epoch 072: Train Acc: 0.7262, Test Acc: 0.7137, ROC AUC: 0.7137, F1: 0.7395, Kappa: 0.4275, Precision: 0.6785, Recall: 0.8125
# Epoch 073: Train Acc: 0.7241, Test Acc: 0.7100, ROC AUC: 0.7100, F1: 0.7010, Kappa: 0.4200, Precision: 0.7234, Recall: 0.6800
# Epoch 074: Train Acc: 0.7284, Test Acc: 0.7150, ROC AUC: 0.7150, F1: 0.7092, Kappa: 0.4300, Precision: 0.7240, Recall: 0.6950

# %%
# prompt: give the best scores for each metric from above, train accuracy and test accuracy score ROC AUC, F1, kappa, precision, recall also

# Find the best scores for each metric
best_train_acc = max(score_train_acc)
best_test_acc = max(score_test_acc)
best_roc_auc = max(score_roc_auc)
best_f1 = max(score_f1)
best_kappa = max(score_kappa)
best_precision = max(score_precision)
best_recall = max(score_recall)

print(f"Best Train Accuracy: {best_train_acc:.4f}")
print(f"Best Test Accuracy: {best_test_acc:.4f}")
print(f"Best ROC AUC: {best_roc_auc:.4f}")
print(f"Best F1 Score: {best_f1:.4f}")
print(f"Best Kappa Score: {best_kappa:.4f}")
print(f"Best Precision: {best_precision:.4f}")
print(f"Best Recall: {best_recall:.4f}")
# Out:
# Best Train Accuracy: 0.7400
# Best Test Accuracy: 0.7300
# Best ROC AUC: 0.7300
# Best F1 Score: 0.7572
# Best Kappa Score: 0.4600
# Best Precision: 0.7908
# Best Recall: 0.9650
